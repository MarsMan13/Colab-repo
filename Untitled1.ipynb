# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

# %%
iris = load_iris()

# %%
iris_data = iris.data
iris_target = iris.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris_data, iris_target, test_size=.2)

dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = dt_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, pred)
# Out:
# 0.9666666666666667

# %%
dir(dt_clf)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_feature_names',
#  '_check_n_features',
#  '_estimator_type',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_prune_tree',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_validate_X_predict',
#  '_validate_data',
#  'apply',
#  'ccp_alpha',
#  'class_weight',
#  'classes_',
#  'cost_complexity_pruning_path',
#  'criterion',
#  'decision_path',
#  'feature_importances_',
#  'fit',
#  'get_depth',
#  'get_n_leaves',
#  'get_params',
#  'max_depth',
#  'max_features',
#  'max_features_',
#  'max_leaf_nodes',
#  'min_impurity_decrease',
#  'min_samples_leaf',
#  'min_samples_split',
#  'min_weight_fraction_leaf',
#  'n_classes_',
#  'n_features_',
#  'n_features_in_',
#  'n_outputs_',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'random_state',
#  'score',
#  'set_params',
#  'splitter',
#  'tree_']

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'max_depth':[2,3,4,5],
    'min_samples_leaf':[1,2,3],
}

grider = GridSearchCV(dt_clf, param_grid=params, scoring="accuracy", n_jobs=-1, cv=3)
grider.fit(iris_data, iris_target)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 4, 5],
#                          'min_samples_leaf': [1, 2, 3]},
#              scoring='accuracy')

# %%
grider.best_score_
# Out:
# 0.9733333333333333

# %%
grider.best_params_
# Out:
# {'max_depth': 3, 'min_samples_leaf': 1}

# %%
import CNN
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-82ec3b02698b> in <module>()
# ----> 1 import CNN
#
# ModuleNotFoundError: No module named 'CNN'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import files

# %%
files.view()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5889fd359d5f> in <module>()
# ----> 1 files.view()
#
# TypeError: view() missing 1 required positional argument: 'filepath'
